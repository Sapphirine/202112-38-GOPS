# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_excel('MCM_NFLIS_Data.xlsx',sheet_name='Data')

# %%
demo_2010 = pd.read_csv('ACS_10_5YR_DP02/ACS_10_5YR_DP02_with_ann.csv')
demo_2011 = pd.read_csv('ACS_11_5YR_DP02/ACS_11_5YR_DP02_with_ann.csv')
demo_2012 = pd.read_csv('ACS_12_5YR_DP02/ACS_12_5YR_DP02_with_ann.csv')
demo_2013 = pd.read_csv('ACS_13_5YR_DP02/ACS_13_5YR_DP02_with_ann.csv')
demo_2014 = pd.read_csv('ACS_14_5YR_DP02/ACS_14_5YR_DP02_with_ann.csv')
demo_2015 = pd.read_csv('ACS_15_5YR_DP02/ACS_15_5YR_DP02_with_ann.csv')
demo_2016 = pd.read_csv('ACS_16_5YR_DP02/ACS_16_5YR_DP02_with_ann.csv')

# %%
#creating empty dataset
for i in range(4,10):
    data["HC01_VC0"+str(i)] = np.nan
for i in range(10,110):
    data["HC01_VC"+str(i)] = np.nan

# %%
#merging data from 2010 to 2016
for index, row in data.iterrows():
    if row['YYYY'] == 2010:
        for i in range(4,10):
            if ("HC01_VC0"+str(i)) in demo_2010.columns:
                data.at[index, "HC01_VC0"+str(i)] = demo_2010.loc[demo_2010['GEO.id2'] == str(row['FIPS_Combined'])]["HC01_VC0"+str(i)].values[0]
        for i in range(10,220):
            try:
                if ("HC01_VC"+str(i)) in demo_2010.columns:
                    data.at[index, "HC01_VC"+str(i)] = demo_2010.loc[demo_2010['GEO.id2'] == str(row['FIPS_Combined'])]["HC01_VC"+str(i)].values[0]
            except:
                continue       
    if row['YYYY'] == 2011:
        for i in range(4,10):
            if ("HC01_VC0"+str(i)) in demo_2011.columns:
                data.at[index, "HC01_VC0"+str(i)] = demo_2011.loc[demo_2011['GEO.id2'] == str(row['FIPS_Combined'])]["HC01_VC0"+str(i)].values[0]
        for i in range(10,220):
            try:
                if ("HC01_VC"+str(i)) in demo_2011.columns:
                    data.at[index, "HC01_VC"+str(i)] = demo_2011.loc[demo_2011['GEO.id2'] == str(row['FIPS_Combined'])]["HC01_VC"+str(i)].values[0]
            except:
                continue        
    if row['YYYY'] == 2012:
        for i in range(4,10):
            if ("HC01_VC0"+str(i)) in demo_2012.columns:
                data.at[index, "HC01_VC0"+str(i)] = demo_2012.loc[demo_2012['GEO.id2'] == str(row['FIPS_Combined'])]["HC01_VC0"+str(i)].values[0]
        for i in range(10,220):
            try:
                if ("HC01_VC"+str(i)) in demo_2012.columns:
                    data.at[index, "HC01_VC"+str(i)] = demo_2012.loc[demo_2012['GEO.id2'] == str(row['FIPS_Combined'])]["HC01_VC"+str(i)].values[0]
            except:
                continue        
    if row['YYYY'] == 2013:
        for i in range(4,10):
            if ("HC01_VC0"+str(i)) in demo_2013.columns:
                data.at[index, "HC01_VC0"+str(i)] = demo_2013.loc[demo_2013['GEO.id2'] == str(row['FIPS_Combined'])]["HC01_VC0"+str(i)].values[0]
        for i in range(10,220):
            try:
                if ("HC01_VC"+str(i)) in demo_2013.columns:
                    data.at[index, "HC01_VC"+str(i)] = demo_2013.loc[demo_2013['GEO.id2'] == str(row['FIPS_Combined'])]["HC01_VC"+str(i)].values[0]
            except:
                continue        
    if row['YYYY'] == 2014:
        for i in range(4,10):
            if ("HC01_VC0"+str(i)) in demo_2014.columns:
                data.at[index, "HC01_VC0"+str(i)] = demo_2014.loc[demo_2014['GEO.id2'] == str(row['FIPS_Combined'])]["HC01_VC0"+str(i)].values[0]
        for i in range(10,220):
            try:
                if ("HC01_VC"+str(i)) in demo_2014.columns:
                    data.at[index, "HC01_VC"+str(i)] = demo_2014.loc[demo_2014['GEO.id2'] == str(row['FIPS_Combined'])]["HC01_VC"+str(i)].values[0]
            except:
                continue        
    if row['YYYY'] == 2015:
        for i in range(4,10):
            if ("HC01_VC0"+str(i)) in demo_2015.columns:
                data.at[index, "HC01_VC0"+str(i)] = demo_2015.loc[demo_2015['GEO.id2'] == str(row['FIPS_Combined'])]["HC01_VC0"+str(i)].values[0]
        for i in range(10,220):
            try:
                if ("HC01_VC"+str(i)) in demo_2015.columns:
                    data.at[index, "HC01_VC"+str(i)] = demo_2015.loc[demo_2015['GEO.id2'] == str(row['FIPS_Combined'])]["HC01_VC"+str(i)].values[0]
            except:
                continue        
    if row['YYYY'] == 2016:
        for i in range(4,10):
            if ("HC01_VC0"+str(i)) in demo_2016.columns:
                data.at[index, "HC01_VC0"+str(i)] = demo_2016.loc[demo_2016['GEO.id2'] == str(row['FIPS_Combined'])]["HC01_VC0"+str(i)].values[0]
        for i in range(10,220):
            try:
                if ("HC01_VC"+str(i)) in demo_2016.columns:
                    data.at[index, "HC01_VC"+str(i)] = demo_2016.loc[demo_2016['GEO.id2'] == str(row['FIPS_Combined'])]["HC01_VC"+str(i)].values[0]
            except:
                continue

# %%
data = data.drop(data.loc[data['YYYY'] == 2017].index)
data_nona = data.dropna(axis=1)
data_nona
# Out:
#        YYYY State  COUNTY  FIPS_State  FIPS_County  FIPS_Combined  \
# 0      2010    KY   ALLEN          21            3          21003
# 1      2010    KY   ALLEN          21            3          21003
# 2      2010    KY  BARREN          21            9          21009
# 3      2010    KY    BATH          21           11          21011
# 4      2010    KY    BATH          21           11          21011
# ...     ...   ...     ...         ...          ...            ...
# 23869  2016    WV    WOOD          54          107          54107
# 23870  2016    WV    WOOD          54          107          54107
# 23871  2016    WV   TYLER          54           95          54095
# 23872  2016    WV   WAYNE          54           99          54099
# 23873  2016    WV    WOOD          54          107          54107
#
#        SubstanceName  DrugReports  TotalDrugReportsCounty  \
# 0          Oxycodone           15                     168
# ...

# %%
columns = data_nona.columns[10:112]
print(columns)
# Out:
# Index(['HC01_VC04', 'HC01_VC06', 'HC01_VC07', 'HC01_VC08', 'HC01_VC09',
#        'HC01_VC10', 'HC01_VC11', 'HC01_VC12', 'HC01_VC13', 'HC01_VC14',
#        ...
#        'HC01_VC200', 'HC01_VC201', 'HC01_VC202', 'HC01_VC203', 'HC01_VC204',
#        'HC01_VC205', 'HC01_VC206', 'HC01_VC207', 'HC01_VC208', 'HC01_VC209'],
#       dtype='object', length=102)

# %%
data_no_feature = data_nona[['YYYY', 'State', 'SubstanceName', 'DrugReports']]
data_no_feature
# Out:
#        YYYY State  SubstanceName  DrugReports
# 0      2010    KY      Oxycodone           15
# 1      2010    KY    Oxymorphone            1
# 2      2010    KY       Morphine            3
# 3      2010    KY  Buprenorphine            1
# 4      2010    KY    Hydrocodone            7
# ...     ...   ...            ...          ...
# 23869  2016    WV       Morphine            4
# 23870  2016    WV       Tramadol            4
# 23871  2016    WV      Oxycodone            1
# 23872  2016    WV      Oxycodone            4
# 23873  2016    WV      Oxycodone            7
#
# [20209 rows x 4 columns]

# %%
data_no_feature_count = data_no_feature.groupby(['YYYY', 'State', 'SubstanceName']).sum()
data_no_feature_count
# Out:
#                              DrugReports
# YYYY State SubstanceName
# 2010 KY    Buprenorphine             460
#            Codeine                    56
#            Fentanyl                   17
#            Heroin                    629
#            Hydrocodone              2863
# ...                                  ...
# 2016 WV    Oxycodone                 477
#            Oxymorphone               102
#            Tramadol                   17
#            U-47700                     2
#            p-Fluorofentanyl            1
#
# [664 rows x 1 columns]

# %%
from sklearn.svm import SVR
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
# State name choosen
# Substance name choosen
Substance_Name = 'Heroin'
State = 'WV'
Substance_no_feature = data_no_feature.loc[(data_no_feature['SubstanceName'] == Substance_Name)&(data_no_feature['State'] == State)]
Substance_no_feature_count = Substance_no_feature.groupby(['YYYY']).sum()
Substance_no_feature_count
# Out:
#       DrugReports
# YYYY
# 2010          902
# 2011          949
# 2012         1175
# 2013         1857
# 2014         1516
# 2015         1135
# 2016         1168

# %%
X =[[2010], [2011], [2012], [2013], [2014]]
X_test = [[2015], [2016]]

# %%
Y = Substance_no_feature_count['DrugReports'].values[0:5]
Y_test = Substance_no_feature_count['DrugReports'].values[5:7]
print(Y)
print(Y_test)
# Out:
# [ 902  949 1175 1857 1516]
# [1135 1168]

# %%
from sklearn.linear_model import Ridge
regr = Ridge()
regr.fit(X, Y)
print(f"test score:", regr.score(X_test, Y_test))
# Out:
# test score: -2420.5098707587185

# %%
Y_predicted = regr.predict(X_test)

# %%
import matplotlib.pyplot as plt 
fig, ax = plt.subplots()
ax.scatter(Y_predicted, Y_test, edgecolors=(0, 0, 1))
ax.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], 'r--', lw=3)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
plt.show()

# %%
# model evaluation for testing set
from sklearn import metrics

mae = metrics.mean_absolute_error(Y_test, Y_predicted)
mse = metrics.mean_squared_error(Y_test, Y_predicted)
r2 = metrics.r2_score(Y_test, Y_predicted)

print("The model performance for testing set")
print("--------------------------------------")
print('MAE is {}'.format(mae))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for testing set
# --------------------------------------
# MAE is 807.9363636363705
# MSE is 659256.0623140611
# R2 score is -2420.5098707587185

# %%
if Substance_Name == 'Heroin':
    feature = ['HC01_VC185','HC01_VC119','HC01_VC36','HC01_VC170','HC01_VC43','HC01_VC85','HC01_VC70','HC01_VC197','HC01_VC86','HC01_VC194']
if Substance_Name == 'Oxycodone':
    feature = ['HC01_VC46','HC01_VC200','HC01_VC11','HC01_VC192','HC01_VC91','HC01_VC47','HC01_VC40','HC01_VC198','HC01_VC67','HC01_VC86']
if Substance_Name == 'Hydrocodone':
    feature = ['HC01_VC196','HC01_VC40','HC01_VC192','HC01_VC200','HC01_VC67','HC01_VC47','HC01_VC194','HC01_VC91','HC01_VC198','HC01_VC86']
if Substance_Name == 'Fentanyl':
    feature = ['HC01_VC46','HC01_VC07','HC01_VC27','HC01_VC89','HC01_VC12','HC01_VC132','HC01_VC28','HC01_VC171','HC01_VC122','HC01_VC133']
if Substance_Name == 'Buprenorphine':
    feature = ['HC01_VC30','HC01_VC200','HC01_VC10','HC01_VC187','HC01_VC37','HC01_VC189','HC01_VC47','HC01_VC44','HC01_VC86','HC01_VC186']

# %%
population = 0
if State == 'OH':
    population = 11536504
if State == 'PA':
    population = 12702379
if State == 'VA':
    population = 8001024
if State == 'KY':
    population = 4339333
if State == 'WV':
    population = 1852994

# %%
X_new =[[2010], [2011], [2012], [2013], [2014]]
X_test_new = [[2015], [2016]]

# %%
# Heroine_feature
feature_count = data_nona.loc[(data_nona['YYYY'] == 2010) & (data_nona['State'] == State) & (data_nona['SubstanceName'] == Substance_Name), 'HC01_VC185'].astype(int).sum()

# %%
feature_count
# Out:
# 2936

# %%
for item in feature:
    for i in range(0,5):
        feature_count = data_nona.loc[(data_nona['YYYY'] == int('201'+str(i))) & (data_nona['State'] == State) & (data_nona['SubstanceName'] == Substance_Name), item].astype(int).sum()
        X_new[i].append(feature_count/population)
    for i in range(5,7):
        feature_count = data_nona.loc[(data_nona['YYYY'] == int('201'+str(i))) & (data_nona['State'] == State) & (data_nona['SubstanceName'] == Substance_Name), item].astype(int).sum()
        X_test_new[i-5].append(feature_count/population)

# %%
print(X_new)
print(X_test_new)
# Out:
# [[2010, 0.001584462766743983, 0.08432137394940296, 0.07875308824529383, 0.005273627437541622, 0.06430889684478201, 0.023932079650554723, 0.0037404330505117662, 0.0016745871816098703, 0.045076238778970684, 0.09698250507017292], [2011, 0.0017528389190682755, 0.09711148552019057, 0.09601488186146312, 0.006349723744383414, 0.07704234336430663, 0.028588327862907274, 0.004563425461712235, 0.001808964303176373, 0.05362996318390669, 0.11628208186319006], [2012, 0.0016486831581753638, 0.0990305419229636, 0.10092261496799235, 0.006269313338305466, 0.080973278920493, 0.030578080662970308, 0.0049719534979605975, 0.0019433414247428755, 0.05544594316009658, 0.12390110275586429], [2013, 0.8511209426474128, 0.8425208068671566, 0.34304212533877604, 0.8032244033170102, 0.3617588616045168, 0.5931152502382631, 0.00964007438772063, 0.1266458499056122, 0.031745380718987755, 0.1567436268007344], [2014, 0.8119599955531427, 0.803871464235718, 0.32689150639451614, 0.7663041542498249, 0.3448710573266832, 0.565
# ...

# %%
regr = Ridge()
regr.fit(X_new, Y)
print(f"test score:", regr.score(X_test_new, Y_test))
# Out:
# test score: -1677.9929315117877

# %%
Y_predicted = regr.predict(X_test_new)

# %%
import matplotlib.pyplot as plt 
fig, ax = plt.subplots()
ax.scatter(Y_predicted, Y_test, edgecolors=(0, 0, 1))
ax.plot([Y_test.min(), Y_test.max()], [Y_test.min(), Y_test.max()], 'r--', lw=3)
ax.set_xlabel('Predicted')
ax.set_ylabel('Actual')
plt.show()

# %%
mae = metrics.mean_absolute_error(Y_test, Y_predicted)
mse = metrics.mean_squared_error(Y_test, Y_predicted)
r2 = metrics.r2_score(Y_test, Y_predicted)

print("The model performance for testing set")
print("--------------------------------------")
print('MAE is {}'.format(mae))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for testing set
# --------------------------------------
# MAE is 674.7462891868927
# MSE is 457105.8256040842
# R2 score is -1677.9929315117877

# %%
d[Substance_Name][State] = X_test_new

# %%
print(d)
# Out:
# {'Heroin': {'OH': [[2015, 1.0009632034106692, 0.989789887820435, 0.39285731621988773, 0.9407551022389452, 0.41888565201381633, 0.6758837859372302, 0.0086329446078292, 0.1365641618986133, 0.020827800172391914, 0.2588669843134454], [2016, 1.0043719483822828, 0.9930471137530053, 0.3954026280405225, 0.9440621699606744, 0.420458572198302, 0.680279398334192, 0.008478391720750064, 0.13520387112074853, 0.02019415933977919, 0.2572189113790452]], 'PA': [[2015, 1.0045935489722044, 0.9938824845330154, 0.4008679791399706, 0.9481393997140221, 0.4279223600555455, 0.6927251973823171, 0.006970269112581195, 0.1680597784084383, 0.024354886592503656, 0.2570705849668003], [2016, 1.0055492754546216, 0.9947596430558402, 0.40251869354551617, 0.9493257916489501, 0.4281489317867149, 0.6960345774598601, 0.0070457667811675275, 0.16540098512255066, 0.023965038360137105, 0.2522544005339472]], 'VA': [[2015, 0.864197757687016, 0.8534731304393037, 0.34179350043194473, 0.8094796366065143, 0.35748036751295836, 0.58353
# ...

# %%
import json

with open('x_test.txt', 'w') as convert_file:
     convert_file.write(json.dumps(d))

# %%
import json

with open('gnn_updated_x_train.txt') as f:
    data = f.read()
       
# reconstructing the data as a dictionary
new_vector_train = json.loads(data)
  

    
with open('gnn_updated_x_test_0.1.txt') as f:
    data_test = f.read()
       
# reconstructing the data as a dictionary
new_vector_test = json.loads(data_test)

# %%
X_train_gnn = new_vector_train[Substance_Name][State]
X_test_gnn = new_vector_test[Substance_Name][State]

# %%
regr = Ridge()
regr.fit(X_train_gnn, Y)
print(f"test score:", regr.score(X_test_gnn, Y_test))
# Out:
# test score: -4.283591604509518

# %%
Y_predicted = regr.predict(X_test_gnn)

# %%
mae = metrics.mean_absolute_error(Y_test, Y_predicted)
mse = metrics.mean_squared_error(Y_test, Y_predicted)
r2 = metrics.r2_score(Y_test, Y_predicted)

print("The model performance for testing set")
print("--------------------------------------")
print('MAE is {}'.format(mae))
print('MSE is {}'.format(mse))
print('R2 score is {}'.format(r2))
# Out:
# The model performance for testing set
# --------------------------------------
# MAE is 2363.9185529928654
# MSE is 8058666.00498803
# R2 score is -4.283591604509518

# %%
drug_report = data_nona.iloc[:, : 10]
drug_report
# Out:
#        YYYY State  COUNTY  FIPS_State  FIPS_County  FIPS_Combined  \
# 0      2010    KY   ALLEN          21            3          21003
# 1      2010    KY   ALLEN          21            3          21003
# 2      2010    KY  BARREN          21            9          21009
# 3      2010    KY    BATH          21           11          21011
# 4      2010    KY    BATH          21           11          21011
# ...     ...   ...     ...         ...          ...            ...
# 23869  2016    WV    WOOD          54          107          54107
# 23870  2016    WV    WOOD          54          107          54107
# 23871  2016    WV   TYLER          54           95          54095
# 23872  2016    WV   WAYNE          54           99          54099
# 23873  2016    WV    WOOD          54          107          54107
#
#        SubstanceName  DrugReports  TotalDrugReportsCounty  \
# 0          Oxycodone           15                     168
# ...

# %%
drug_report = drug_report.loc[drug_report['YYYY'] == 2016]
drug_report
# Out:
#        YYYY State    COUNTY  FIPS_State  FIPS_County  FIPS_Combined  \
# 3947   2016    KY     ADAIR          21            1          21001
# 3948   2016    KY     ALLEN          21            3          21003
# 3949   2016    KY     ALLEN          21            3          21003
# 3950   2016    KY  ANDERSON          21            5          21005
# 3951   2016    KY  ANDERSON          21            5          21005
# ...     ...   ...       ...         ...          ...            ...
# 23869  2016    WV      WOOD          54          107          54107
# 23870  2016    WV      WOOD          54          107          54107
# 23871  2016    WV     TYLER          54           95          54095
# 23872  2016    WV     WAYNE          54           99          54099
# 23873  2016    WV      WOOD          54          107          54107
#
#        SubstanceName  DrugReports  TotalDrugReportsCounty  \
# 3947   Buprenorphine            7                     115
# ...

# %%
drug_report = drug_report.loc[drug_report['SubstanceName'] == "Fentanyl"]
State = "WV"
population = 0
if State == 'OH':
    population = 11536504
if State == 'PA':
    population = 12702379
if State == 'VA':
    population = 8001024
if State == 'KY':
    population = 4339333
if State == 'WV':
    population = 1852994

# %%
Heroin_count = (drug_report.loc[(drug_report['State'] == State), 'DrugReports'].astype(int).sum())/population
print(Heroin_count)
# Out:
# 0.00010469542804779724
