# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_excel('MCM_NFLIS_Data.xlsx',sheet_name='Data')
data.head()
# Out:
#    YYYY State  COUNTY  FIPS_State  FIPS_County  FIPS_Combined  SubstanceName  \
# 0  2010    KY   ALLEN          21            3          21003      Oxycodone
# 1  2010    KY   ALLEN          21            3          21003    Oxymorphone
# 2  2010    KY  BARREN          21            9          21009       Morphine
# 3  2010    KY    BATH          21           11          21011  Buprenorphine
# 4  2010    KY    BATH          21           11          21011    Hydrocodone
#
#    DrugReports  TotalDrugReportsCounty  TotalDrugReportsState
# 0           15                     168                  29588
# 1            1                     168                  29588
# 2            3                     383                  29588
# 3            1                      81                  29588
# 4            7                      81                  29588

# %%
name = set(data['SubstanceName'])
name = list(name)
#  Create a dictionary to save SubstanceName Of DrugReports All worth ,
DrugReports_dick = {
   
    }
for i in name:
    DrugReports_dick[i] = sum(data[data['SubstanceName'] == i]['DrugReports'])
print(DrugReports_dick)
#  Then sort and extract the first five values 
DrugReports_dick = sorted(DrugReports_dick.items(), key=lambda item:item[1])
DrugReports_dic = dict(DrugReports_dick)
# Out:
# {'Cyclopropyl fentanyl': 941, 'Dihydrocodeine': 13, 'Thebaine': 11, 'Opiates': 60, 'U-47700': 1592, 'Hydrocodeinone': 3, 'Benzylfentanyl': 152, 'Fluorobutyryl fentanyl ': 23, 'Cyclopropyl/Crotonyl Fentanyl': 26, 'Isobutyryl fentanyl': 4, '4-Methylfentanyl': 5, 'Furanyl fentanyl': 3219, 'p-methoxybutyryl fentanyl': 1, 'o-Fluorofentanyl': 7, 'Acetyldihydrocodeine': 5, 'Remifentanil': 1, 'Cyclopentyl fentanyl': 1, 'Methadone': 8713, 'p-Fluorofentanyl': 7, 'Tetrahydrofuran fentanyl': 6, 'Metazocine': 1, '3-Methylfentanyl': 1212, '3-Fluorofentanyl': 1, 'Hydrocodone': 47370, 'Opium': 31, 'Crotonyl fentanyl': 39, 'Buprenorphine': 34839, 'Oxycodone': 110173, 'Fluorofentanyl': 3, '4-Fluoroisobutyryl fentanyl': 698, 'Phenyl fentanyl': 64, 'p-Fluorobutyryl fentanyl': 16, 'Alphaprodine': 1, 'Fentanyl': 47339, 'Acryl fentanyl': 1365, 'Nalbuphine': 1, 'Meperidine': 104, 'Desmethylprodine ': 15, 'trans-3-Methylfentanyl': 23, 'Propoxyphene': 571, 'Butorphanol': 8, 'Dihydromorphone': 1, 'Methorphan':
# ...

# %%
print(DrugReports_dick)
# Out:
# [('p-methoxybutyryl fentanyl', 1), ('Remifentanil', 1), ('Cyclopentyl fentanyl', 1), ('Metazocine', 1), ('3-Fluorofentanyl', 1), ('Alphaprodine', 1), ('Nalbuphine', 1), ('Dihydromorphone', 1), ('MT-45', 2), ('Levorphanol', 2), ('Hydrocodeinone', 3), ('Fluorofentanyl', 3), ('3,4-Methylenedioxy U-47700', 3), ('Isobutyryl fentanyl', 4), ('4-Methylfentanyl', 5), ('Acetyldihydrocodeine', 5), ('Tetrahydrofuran fentanyl', 6), ('o-Fluorofentanyl', 7), ('p-Fluorofentanyl', 7), ('U-51754', 7), ('Furanyl/3-Furanyl fentanyl', 7), ('Butorphanol', 8), ('Thebaine', 11), ('Dihydrocodeine', 13), ('Acetylcodeine', 13), ('Pethidine', 14), ('Desmethylprodine ', 15), ('p-Fluorobutyryl fentanyl', 16), ('U-49900', 17), ('Valeryl fentanyl', 21), ('Fluorobutyryl fentanyl ', 23), ('trans-3-Methylfentanyl', 23), ('cis-3-methylfentanyl', 25), ('Cyclopropyl/Crotonyl Fentanyl', 26), ('Opium', 31), ('U-48800', 35), ('Crotonyl fentanyl', 39), ('Pentazocine', 55), ('Opiates', 60), ('Phenyl fentanyl', 64), ('Dextropr
# ...

# %%
import seaborn as sns
plt.figure(figsize=(16, 8), facecolor='white')
keys = list(DrugReports_dic.keys())
# get values in the same order as keys, and parse percentage values
vals = [float(DrugReports_dic[k]) for k in keys]
sns.set(rc={'figure.figsize':(16,8)})
sns.barplot(x=keys, y=vals)
plt.grid(False)

# %%
DrugReports_five = np.array(DrugReports_dick)[-10:]
plt.figure(figsize=(10,10))

plt.pie(DrugReports_five[:,1],
        autopct='%1.1f%%',
        shadow=False,
        startangle=150)
plt.title("Total Reported Quantity in 7 Years", fontsize=18)
plt.savefig("Substance.png")

ax.set_facecolor('white')
plt.xticks(None, size=7)


plt.legend(labels=DrugReports_five[:,0], facecolor='white', fontsize=12)
plt.show()
plt.savefig('five_pie.jpg')

# %%
five_keys = DrugReports_dick[-5:]
five = []
for item in five_keys:
    five.append(item[0])

print(five)
# Out:
# ['Buprenorphine', 'Fentanyl', 'Hydrocodone', 'Oxycodone', 'Heroin']

# %%
for i in range(4,10):
    data["HC03_VC0"+str(i)] = np.nan
for i in range(10,50):
    data["HC03_VC"+str(i)] = np.nan

# %%
demo_2010 = pd.read_csv('ACS_10_5YR_DP02/ACS_10_5YR_DP02_with_ann.csv')
demo_2010.head()
# Out:
#            GEO.id GEO.id2          GEO.display-label  \
# 0              Id     Id2                  Geography
# 1  0500000US21001   21001     Adair County, Kentucky
# 2  0500000US21003   21003     Allen County, Kentucky
# 3  0500000US21005   21005  Anderson County, Kentucky
# 4  0500000US21007   21007   Ballard County, Kentucky
#
#                                          HC01_VC03  \
# 0  Estimate; HOUSEHOLDS BY TYPE - Total households
# 1                                             7272
# 2                                             7811
# 3                                             8319
# 4                                             3363
#
#                                            HC02_VC03  \
# 0  Estimate Margin of Error; HOUSEHOLDS BY TYPE -...
# 1                                                270
# 2                                                291
# 3                                                205
# 4                                                146
#
# ...

# %%
demo_2011 = pd.read_csv('ACS_11_5YR_DP02/ACS_11_5YR_DP02_with_ann.csv')
demo_2011.head()
# Out:
#            GEO.id GEO.id2          GEO.display-label  \
# 0              Id     Id2                  Geography
# 1  0500000US21001   21001     Adair County, Kentucky
# 2  0500000US21003   21003     Allen County, Kentucky
# 3  0500000US21005   21005  Anderson County, Kentucky
# 4  0500000US21007   21007   Ballard County, Kentucky
#
#                                          HC01_VC03  \
# 0  Estimate; HOUSEHOLDS BY TYPE - Total households
# 1                                             7193
# 2                                             7849
# 3                                             8386
# 4                                             3358
#
#                                            HC02_VC03  \
# 0  Margin of Error; HOUSEHOLDS BY TYPE - Total ho...
# 1                                                267
# 2                                                252
# 3                                               1558
# 4                                                145
#
# ...

# %%
demo_2012 = pd.read_csv('ACS_12_5YR_DP02/ACS_12_5YR_DP02_with_ann.csv')
demo_2012.head()
# Out:
#            GEO.id GEO.id2          GEO.display-label  \
# 0              Id     Id2                  Geography
# 1  0500000US21001   21001     Adair County, Kentucky
# 2  0500000US21003   21003     Allen County, Kentucky
# 3  0500000US21005   21005  Anderson County, Kentucky
# 4  0500000US21007   21007   Ballard County, Kentucky
#
#                                          HC01_VC03  \
# 0  Estimate; HOUSEHOLDS BY TYPE - Total households
# 1                                             7236
# 2                                             7980
# 3                                             8369
# 4                                             3379
#
#                                            HC02_VC03  \
# 0  Margin of Error; HOUSEHOLDS BY TYPE - Total ho...
# 1                                                270
# 2                                                230
# 3                                                210
# 4                                                140
#
# ...

# %%
demo_2013 = pd.read_csv('ACS_13_5YR_DP02/ACS_13_5YR_DP02_with_ann.csv')
demo_2013.head()
# Out:
#            GEO.id GEO.id2          GEO.display-label  \
# 0              Id     Id2                  Geography
# 1  0500000US21001   21001     Adair County, Kentucky
# 2  0500000US21003   21003     Allen County, Kentucky
# 3  0500000US21005   21005  Anderson County, Kentucky
# 4  0500000US21007   21007   Ballard County, Kentucky
#
#                                          HC01_VC03  \
# 0  Estimate; HOUSEHOLDS BY TYPE - Total households
# 1                                             7241
# 2                                             8061
# 3                                             8323
# 4                                             3327
#
#                                            HC02_VC03  \
# 0  Margin of Error; HOUSEHOLDS BY TYPE - Total ho...
# 1                                                229
# 2                                                223
# 3                                                234
# 4                                                122
#
# ...

# %%
demo_2014 = pd.read_csv('ACS_14_5YR_DP02/ACS_14_5YR_DP02_with_ann.csv')
demo_2014.head()
# Out:
#            GEO.id GEO.id2          GEO.display-label  \
# 0              Id     Id2                  Geography
# 1  0500000US21001   21001     Adair County, Kentucky
# 2  0500000US21003   21003     Allen County, Kentucky
# 3  0500000US21005   21005  Anderson County, Kentucky
# 4  0500000US21007   21007   Ballard County, Kentucky
#
#                                          HC01_VC03  \
# 0  Estimate; HOUSEHOLDS BY TYPE - Total households
# 1                                             7124
# 2                                             8057
# 3                                             8353
# 4                                             3279
#
#                                            HC02_VC03  \
# 0  Margin of Error; HOUSEHOLDS BY TYPE - Total ho...
# 1                                                257
# 2                                                223
# 3                                                261
# 4                                                126
#
# ...

# %%
demo_2015 = pd.read_csv('ACS_15_5YR_DP02/ACS_15_5YR_DP02_with_ann.csv')
demo_2015.head()
# Out:
#            GEO.id GEO.id2          GEO.display-label  \
# 0              Id     Id2                  Geography
# 1  0500000US21001   21001     Adair County, Kentucky
# 2  0500000US21003   21003     Allen County, Kentucky
# 3  0500000US21005   21005  Anderson County, Kentucky
# 4  0500000US21007   21007   Ballard County, Kentucky
#
#                                          HC01_VC03  \
# 0  Estimate; HOUSEHOLDS BY TYPE - Total households
# 1                                             7048
# 2                                             7774
# 3                                             8446
# 4                                             3288
#
#                                            HC02_VC03  \
# 0  Margin of Error; HOUSEHOLDS BY TYPE - Total ho...
# 1                                                215
# 2                                                253
# 3                                                272
# 4                                                104
#
# ...

# %%
demo_2016 = pd.read_csv('ACS_16_5YR_DP02/ACS_16_5YR_DP02_with_ann.csv')
demo_2016.head()
# Out:
#            GEO.id GEO.id2          GEO.display-label  \
# 0              Id     Id2                  Geography
# 1  0500000US21001   21001     Adair County, Kentucky
# 2  0500000US21003   21003     Allen County, Kentucky
# 3  0500000US21005   21005  Anderson County, Kentucky
# 4  0500000US21007   21007   Ballard County, Kentucky
#
#                                          HC01_VC03  \
# 0  Estimate; HOUSEHOLDS BY TYPE - Total households
# 1                                             7126
# 2                                             7705
# 3                                             8554
# 4                                             3252
#
#                                            HC02_VC03  \
# 0  Margin of Error; HOUSEHOLDS BY TYPE - Total ho...
# 1                                                253
# 2                                                255
# 3                                                210
# 4                                                132
#
# ...

# %%
data.head()
# Out:
#    YYYY State  COUNTY  FIPS_State  FIPS_County  FIPS_Combined  SubstanceName  \
# 0  2010    KY   ALLEN          21            3          21003      Oxycodone
# 1  2010    KY   ALLEN          21            3          21003    Oxymorphone
# 2  2010    KY  BARREN          21            9          21009       Morphine
# 3  2010    KY    BATH          21           11          21011  Buprenorphine
# 4  2010    KY    BATH          21           11          21011    Hydrocodone
#
#    DrugReports  TotalDrugReportsCounty  TotalDrugReportsState  ...  HC03_VC40  \
# 0           15                     168                  29588  ...        NaN
# 1            1                     168                  29588  ...        NaN
# 2            3                     383                  29588  ...        NaN
# 3            1                      81                  29588  ...        NaN
# 4            7                      81                  29588  ...        NaN
#
# ...

# %%
for index, row in data.iterrows():
    if row['YYYY'] == 2010:
        for i in range(4,10):
            if ("HC03_VC0"+str(i)) in demo_2010.columns:
                data.at[index, "HC03_VC0"+str(i)] = demo_2010.loc[demo_2010['GEO.id2'] == str(row['FIPS_Combined'])]["HC03_VC0"+str(i)].values[0]
        for i in range(10,50):
            try:
                if ("HC03_VC"+str(i)) in demo_2010.columns:
                    data.at[index, "HC03_VC"+str(i)] = demo_2010.loc[demo_2010['GEO.id2'] == str(row['FIPS_Combined'])]["HC03_VC"+str(i)].values[0]
            except:
                continue       
    if row['YYYY'] == 2011:
        for i in range(4,10):
            if ("HC03_VC0"+str(i)) in demo_2011.columns:
                data.at[index, "HC03_VC0"+str(i)] = demo_2011.loc[demo_2011['GEO.id2'] == str(row['FIPS_Combined'])]["HC03_VC0"+str(i)].values[0]
        for i in range(10,50):
            try:
                if ("HC03_VC"+str(i)) in demo_2011.columns:
                    data.at[index, "HC03_VC"+str(i)] = demo_2011.loc[demo_2011['GEO.id2'] == str(row['FIPS_Combined'])]["HC03_VC"+str(i)].values[0]
            except:
                continue        
    if row['YYYY'] == 2012:
        for i in range(4,10):
            if ("HC03_VC0"+str(i)) in demo_2012.columns:
                data.at[index, "HC03_VC0"+str(i)] = demo_2012.loc[demo_2012['GEO.id2'] == str(row['FIPS_Combined'])]["HC03_VC0"+str(i)].values[0]
        for i in range(10,50):
            try:
                if ("HC03_VC"+str(i)) in demo_2012.columns:
                    data.at[index, "HC03_VC"+str(i)] = demo_2012.loc[demo_2012['GEO.id2'] == str(row['FIPS_Combined'])]["HC03_VC"+str(i)].values[0]
            except:
                continue        
    if row['YYYY'] == 2013:
        for i in range(4,10):
            if ("HC03_VC0"+str(i)) in demo_2013.columns:
                data.at[index, "HC03_VC0"+str(i)] = demo_2013.loc[demo_2013['GEO.id2'] == str(row['FIPS_Combined'])]["HC03_VC0"+str(i)].values[0]
        for i in range(10,50):
            try:
                if ("HC03_VC"+str(i)) in demo_2013.columns:
                    data.at[index, "HC03_VC"+str(i)] = demo_2013.loc[demo_2013['GEO.id2'] == str(row['FIPS_Combined'])]["HC03_VC"+str(i)].values[0]
            except:
                continue        
    if row['YYYY'] == 2014:
        for i in range(4,10):
            if ("HC03_VC0"+str(i)) in demo_2014.columns:
                data.at[index, "HC03_VC0"+str(i)] = demo_2014.loc[demo_2014['GEO.id2'] == str(row['FIPS_Combined'])]["HC03_VC0"+str(i)].values[0]
        for i in range(10,50):
            try:
                if ("HC03_VC"+str(i)) in demo_2014.columns:
                    data.at[index, "HC03_VC"+str(i)] = demo_2014.loc[demo_2014['GEO.id2'] == str(row['FIPS_Combined'])]["HC03_VC"+str(i)].values[0]
            except:
                continue        
    if row['YYYY'] == 2015:
        for i in range(4,10):
            if ("HC03_VC0"+str(i)) in demo_2015.columns:
                data.at[index, "HC03_VC0"+str(i)] = demo_2015.loc[demo_2015['GEO.id2'] == str(row['FIPS_Combined'])]["HC03_VC0"+str(i)].values[0]
        for i in range(10,50):
            try:
                if ("HC03_VC"+str(i)) in demo_2015.columns:
                    data.at[index, "HC03_VC"+str(i)] = demo_2015.loc[demo_2015['GEO.id2'] == str(row['FIPS_Combined'])]["HC03_VC"+str(i)].values[0]
            except:
                continue        
    if row['YYYY'] == 2016:
        for i in range(4,10):
            if ("HC03_VC0"+str(i)) in demo_2016.columns:
                data.at[index, "HC03_VC0"+str(i)] = demo_2016.loc[demo_2016['GEO.id2'] == str(row['FIPS_Combined'])]["HC03_VC0"+str(i)].values[0]
        for i in range(10,50):
            try:
                if ("HC03_VC"+str(i)) in demo_2016.columns:
                    data.at[index, "HC03_VC"+str(i)] = demo_2016.loc[demo_2016['GEO.id2'] == str(row['FIPS_Combined'])]["HC03_VC"+str(i)].values[0]
            except:
                continue

# %%
data.head()
# Out:
#    YYYY State  COUNTY  FIPS_State  FIPS_County  FIPS_Combined  SubstanceName  \
# 0  2010    KY   ALLEN          21            3          21003      Oxycodone
# 1  2010    KY   ALLEN          21            3          21003    Oxymorphone
# 2  2010    KY  BARREN          21            9          21009       Morphine
# 3  2010    KY    BATH          21           11          21011  Buprenorphine
# 4  2010    KY    BATH          21           11          21011    Hydrocodone
#
#    DrugReports  TotalDrugReportsCounty  TotalDrugReportsState  ...  HC03_VC40  \
# 0           15                     168                  29588  ...       12.3
# 1            1                     168                  29588  ...       12.3
# 2            3                     383                  29588  ...       10.7
# 3            1                      81                  29588  ...       15.4
# 4            7                      81                  29588  ...       15.4
#
# ...

# %%
data['popultion'] = 0
data
# Out:
#        YYYY State   COUNTY  FIPS_State  FIPS_County  FIPS_Combined  \
# 0      2010    KY    ALLEN          21            3          21003
# 1      2010    KY    ALLEN          21            3          21003
# 2      2010    KY   BARREN          21            9          21009
# 3      2010    KY     BATH          21           11          21011
# 4      2010    KY     BATH          21           11          21011
# ...     ...   ...      ...         ...          ...            ...
# 24057  2017    WV   TUCKER          54           93          54093
# 24058  2017    WV  WEBSTER          54          101          54101
# 24059  2017    WV     WOOD          54          107          54107
# 24060  2017    WV     WOOD          54          107          54107
# 24061  2017    WV     WOOD          54          107          54107
#
#          SubstanceName  DrugReports  TotalDrugReportsCounty  \
# 0            Oxycodone           15                     168
# ...

# %%
population = pd.read_csv('maps-county2011.csv')
population
# Out:
#       00000          United States 308,745,538 309,330,219 311,591,917  \
# 0      1000               .Alabama   4,779,735   4,785,401   4,802,740
# 1      1001       ..Autauga County      54,571      54,637      55,267
# 2      1003       ..Baldwin County     182,265     183,259     186,717
# 3      1005       ..Barbour County      27,457      27,390      27,119
# 4      1007          ..Bibb County      22,919      22,880      22,766
# ...     ...                    ...         ...         ...         ...
# 3268  72145  ..Vega Baja Municipio      59,662      59,549      59,172
# 3269  72147    ..Vieques Municipio       9,301       9,312       9,350
# 3270  72149   ..Villalba Municipio      26,073      26,019      25,767
# 3271  72151    ..Yabucoa Municipio      37,941      37,892      37,665
# 3272  72153      ..Yauco Municipio      42,043      41,929      41,486
#
#      2,846,379  0.9 2,261,698  0.7    88.2 3,531,932  Unnamed: 11  \
# ...

# %%
int(''.join(population['308,745,538'][0].split(',')))
# Out:
# 4779735

# %%
for idx in data.index:
#     print(idx)
#     print(data.at[idx, 'FIPS_Combined'])
#     print(population.loc[population['00000'] == data.at[idx, 'FIPS_Combined']]['308,745,538'].values[0])
    data.at[idx, 'popultion'] = int(''.join(population.loc[population['00000'] == data.at[idx, 'FIPS_Combined']]['308,745,538'].values[0].split(',')))

# %%
data['population_ratio'] = data['DrugReports']/data['popultion']

# %%
data
# Out:
#        YYYY State   COUNTY  FIPS_State  FIPS_County  FIPS_Combined  \
# 0      2010    KY    ALLEN          21            3          21003
# 1      2010    KY    ALLEN          21            3          21003
# 2      2010    KY   BARREN          21            9          21009
# 3      2010    KY     BATH          21           11          21011
# 4      2010    KY     BATH          21           11          21011
# ...     ...   ...      ...         ...          ...            ...
# 24057  2017    WV   TUCKER          54           93          54093
# 24058  2017    WV  WEBSTER          54          101          54101
# 24059  2017    WV     WOOD          54          107          54107
# 24060  2017    WV     WOOD          54          107          54107
# 24061  2017    WV     WOOD          54          107          54107
#
#          SubstanceName  DrugReports  TotalDrugReportsCounty  \
# 0            Oxycodone           15                     168
# ...

# %%
data = data.drop(data.loc[data['YYYY'] == 2017].index)
data
# Out:
#        YYYY State  COUNTY  FIPS_State  FIPS_County  FIPS_Combined  \
# 0      2010    KY   ALLEN          21            3          21003
# 1      2010    KY   ALLEN          21            3          21003
# 2      2010    KY  BARREN          21            9          21009
# 3      2010    KY    BATH          21           11          21011
# 4      2010    KY    BATH          21           11          21011
# ...     ...   ...     ...         ...          ...            ...
# 23869  2016    WV    WOOD          54          107          54107
# 23870  2016    WV    WOOD          54          107          54107
# 23871  2016    WV   TYLER          54           95          54095
# 23872  2016    WV   WAYNE          54           99          54099
# 23873  2016    WV    WOOD          54          107          54107
#
#        SubstanceName  DrugReports  TotalDrugReportsCounty  \
# 0          Oxycodone           15                     168
# ...

# %%
data_nona = data.dropna(axis=1)
data_nona
# Out:
#        YYYY State  COUNTY  FIPS_State  FIPS_County  FIPS_Combined  \
# 0      2010    KY   ALLEN          21            3          21003
# 1      2010    KY   ALLEN          21            3          21003
# 2      2010    KY  BARREN          21            9          21009
# 3      2010    KY    BATH          21           11          21011
# 4      2010    KY    BATH          21           11          21011
# ...     ...   ...     ...         ...          ...            ...
# 23869  2016    WV    WOOD          54          107          54107
# 23870  2016    WV    WOOD          54          107          54107
# 23871  2016    WV   TYLER          54           95          54095
# 23872  2016    WV   WAYNE          54           99          54099
# 23873  2016    WV    WOOD          54          107          54107
#
#        SubstanceName  DrugReports  TotalDrugReportsCounty  \
# 0          Oxycodone           15                     168
# ...

# %%
data_Heroin = data_nona.drop(data_nona.loc[data_nona['SubstanceName'] != 'Heroin'].index)
data_Heroin.head()
# Out:
#     YYYY State     COUNTY  FIPS_State  FIPS_County  FIPS_Combined  \
# 12  2010    KY    CARROLL          21           41          21041
# 23  2010    KY      BOONE          21           15          21015
# 26  2010    KY       BOYD          21           19          21019
# 30  2010    KY  BREATHITT          21           25          21025
# 42  2010    KY    ELLIOTT          21           63          21063
#
#    SubstanceName  DrugReports  TotalDrugReportsCounty  TotalDrugReportsState  \
# 12        Heroin            8                      99                  29588
# 23        Heroin           47                     299                  29588
# 26        Heroin            5                     504                  29588
# 30        Heroin            4                     162                  29588
# 42        Heroin            1                      91                  29588
#
#     ...  HC03_VC38  HC03_VC39  HC03_VC40  HC03_VC43  HC03_VC44  HC03_VC45  \
# ...

# %%
columns = data_Heroin.columns
print(columns[10:38])
# Out:
# Index(['HC03_VC04', 'HC03_VC06', 'HC03_VC07', 'HC03_VC08', 'HC03_VC09',
#        'HC03_VC10', 'HC03_VC11', 'HC03_VC12', 'HC03_VC13', 'HC03_VC14',
#        'HC03_VC17', 'HC03_VC18', 'HC03_VC26', 'HC03_VC27', 'HC03_VC28',
#        'HC03_VC29', 'HC03_VC30', 'HC03_VC31', 'HC03_VC36', 'HC03_VC37',
#        'HC03_VC38', 'HC03_VC39', 'HC03_VC40', 'HC03_VC43', 'HC03_VC44',
#        'HC03_VC45', 'HC03_VC46', 'HC03_VC47'],
#       dtype='object')

# %%
Heroin_corr = []
for heading in columns[10:38]:
    column_1 = data_Heroin[heading]
    column_2 = data_Heroin["population_ratio"]
    correlation = column_2.corr(column_1)
    Heroin_corr.append(correlation)

print(Heroin_corr)
# Out:
# [-0.10400429621971194, 0.13377523852360595, -0.20586929881154273, -0.1722237815673773, -0.051752795664123205, 0.20087099317720086, -0.08155828008462669, 0.21760367661276983, -0.0019241872259857474, -0.1623837586904302, 0.004848543169316601, -0.04577496945670738, 0.23735838721368208, 0.17872661627018002, -0.19469862180232328, 0.20763037334303855, 0.013543854726976072, 0.182275895564, 0.23810442959825762, -0.1544650438123632, 0.17491013484758133, -0.1517419362016293, -0.16997959371342988, 0.23941039839901931, -0.16023722930131126, 0.16906286747899416, -0.20694470152610783, -0.03841541965996428]

# %%
df = pd.DataFrame({'lab':columns[10:38], 'Heroin_corr':Heroin_corr})
ax = df.plot.bar(x='lab', y='Heroin_corr', rot=0)

# %%
data_Oxycodone = data_nona.drop(data_nona.loc[data_nona['SubstanceName'] != 'Oxycodone'].index)
data_Oxycodone.head()
Oxycodone_corr = []
for heading in columns[10:38]:
    column_1 = data_Oxycodone[heading]
    column_2 = data_Oxycodone["population_ratio"]
    correlation = column_2.corr(column_1)
    Oxycodone_corr.append(correlation)

print(Oxycodone_corr)
df = pd.DataFrame({'lab':columns[10:38], 'Oxycodone_corr':Oxycodone_corr})
ax = df.plot.bar(x='lab', y='Oxycodone_corr', rot=0)
# Out:
# [0.036710370384306586, -0.14119330743066993, 0.1177432653239, 0.1277815034308564, 0.18109817839968326, -0.09129649412442886, 0.21157779275660632, -0.13155726744259538, 0.043721472638428814, 0.13912274372655664, 0.10279968020576723, -0.06985434818244884, -0.11228612165329885, -0.15761140034994084, 0.13320389882563494, -0.12220761060001915, 0.004403645881156988, -0.12182950812429708, -0.1148357465058654, 0.0738591348191095, -0.1408954231100418, 0.1617794774475692, 0.2340602402255373, -0.11122409035336271, 0.08905992570464127, -0.14179065276337321, 0.19925887827574024, 0.2205032005588025]

# %%
data_Hydrocodone = data.drop(data.loc[data['SubstanceName'] != 'Hydrocodone'].index)
data_Hydrocodone.head()
Hydrocodone_corr = []
for heading in columns[10:38]:
    column_1 = data_Hydrocodone[heading]
    column_2 = data_Hydrocodone["population_ratio"]
    correlation = column_2.corr(column_1)
    Hydrocodone_corr.append(correlation)

print(Hydrocodone_corr)
df = pd.DataFrame({'lab':columns[10:38], 'Hydrocodone_corr':Hydrocodone_corr})
ax = df.plot.bar(x='lab', y='Hydrocodone_corr', rot=0)
# Out:
# [0.025649610864393768, -0.14948471246983394, 0.09630037882695788, 0.0893469743277859, 0.15125932666940783, -0.09230609150830694, 0.14654230595527154, -0.11781721136469588, 0.06724707402603061, 0.14427750019027152, -0.03697897345999512, 0.0662603845538626, -0.15615404175699615, -0.11235535088310024, 0.08873564664708296, -0.12179362444677366, -0.005383685063237939, -0.16214915375720054, -0.1582276494863365, 0.07070856762538796, -0.12090011745100658, 0.19863172166232168, 0.2240914661689089, -0.15481208692927612, 0.07106179045258709, -0.11641954051108493, 0.20932937249024683, 0.24280554666261445]

# %%
data_Fentanyl = data.drop(data.loc[data['SubstanceName'] != 'Fentanyl'].index)
data_Fentanyl.head()
Fentanyl_corr = []
for heading in columns[10:38]:
    column_1 = data_Fentanyl[heading]
    column_2 = data_Fentanyl["population_ratio"]
    correlation = column_2.corr(column_1)
    Fentanyl_corr.append(correlation)

print(Fentanyl_corr)
df = pd.DataFrame({'lab':columns[10:38], 'Fentanyl_corr':Fentanyl_corr})
ax = df.plot.bar(x='lab', y='Fentanyl_corr', rot=0)
# Out:
# [-0.058210599441894016, 0.14445779973053285, -0.234402123012633, -0.20897670537526244, -0.10209699205571207, 0.22738646764595302, -0.1324488738005532, 0.23748639003266298, -0.049470282359250224, -0.1970296142737174, -0.033226788939551305, 0.07413553037317476, 0.11487663226662999, 0.23557418037344333, -0.23827852966045054, 0.22794642698632267, 0.032669125380519935, 0.15418715915050715, 0.11488104059208272, -0.19244407408547656, 0.2137936454002242, -0.1865812322355804, -0.19681642792419182, 0.1156364094288913, -0.19076223793455244, 0.2088405037892774, -0.22829458513555678, -0.04614239180035637]

# %%
data_Buprenorphine = data.drop(data.loc[data['SubstanceName'] != 'Buprenorphine'].index)
data_Buprenorphine.head()
Buprenorphine_corr = []
for heading in columns[10:38]:
    column_1 = data_Buprenorphine[heading]
    column_2 = data_Buprenorphine["population_ratio"]
    correlation = column_2.corr(column_1)
    Buprenorphine_corr.append(correlation)

print(Buprenorphine_corr)
df = pd.DataFrame({'lab':columns[10:38], 'Buprenorphine_corr':Buprenorphine_corr})
ax = df.plot.bar(x='lab', y='Buprenorphine_corr', rot=0)
# Out:
# [0.0012718302165587423, 0.11407147108263287, -0.17424996588681202, -0.1485907422138549, -0.10220110675832718, 0.18233924619467382, -0.12169225117926366, 0.14440465861179008, -0.035477177201739714, -0.11186791032559626, -0.06285695882209717, 0.14515755575360528, -0.08213031135411845, 0.1666137437669382, -0.14255825528400154, 0.14289638672380436, 0.1778214555798877, 0.020287687150422663, -0.0816552098745955, -0.18855643180788084, 0.15368200635723825, 0.05340893304233114, -0.09093825339682983, -0.08114082045645742, -0.2067326543724812, 0.15971000991929746, -0.07760885034406143, 0.2035296286333309]

# %%
import matplotlib.patches as mpatches
combine_crime_rate = pd.DataFrame({'Heroin':Heroin_corr, 'Oxycodone':Oxycodone_corr, 'Hydrocodone':Hydrocodone_corr, 'Fentanyl':Fentanyl_corr, 'Buprenorphine':Buprenorphine_corr}, index=columns[10:38])
ax = combine_crime_rate.plot.bar(rot=0, width=0.6, figsize=(24,6), grid=False)
ax.set_facecolor('white')
plt.xticks(None, size=7)
red_patch = mpatches.Patch(color='white')
ax.legend(facecolor='white', fontsize=12)
ax.get_yaxis().set_visible(True)
plt.yticks(fontsize=12)
ax.set_xlabel("Demographic Features", size=20)
ax.set_ylabel("Correlation", size=20)
plt.title("Correlation between Socio-demogrphic Features with Opioids Increase", size=20)
# Out:
# Text(0.5, 1.0, 'Correlation between Socio-demogrphic Features with Opioids Increase')

# %%
x = list(range(5, 38))
y_svr_mse =  [25018.320012227487, 29184.924298265236, 29853.28485143378, 32856.12125785422, 33049.58754002238, 33698.804834730945, 38947.24547077893, 39034.702413317085, 39265.22251231376, 39297.82369348365, 39974.98082208515, 39971.59022856221, 39977.56845171226, 40308.807478827875, 40400.02671682135, 40500.235452525834, 40559.84873428391, 40783.85519394011, 40950.96678525294, 41181.371243074675, 41169.4420925689, 41331.80513824407, 41264.51816906208, 41596.05871908588, 41691.49457947483, 41903.97736727451, 42348.118935956256, 42477.10355517742, 42535.4080573282, 42721.44049817885, 43320.514597395675, 43330.70217764923, 43409.847767629064]
y_ridge_mse= [3161.598805092824, 3131.3482974068866, 3140.296576735606, 3146.030068068253, 1512.4992797193675, 1463.3038396251463, 1440.546933353257, 1430.4360342011203, 1419.7434163062921, 1452.558451131759, 3341.9946174470783, 3369.2576864007224, 3597.759038325299, 3540.2736064519854, 3424.22316411123, 3442.9353874063736, 4179.029764855854, 3466.907410568297, 3896.7814693931623, 4215.971998135192, 3807.311051044505, 3390.4552383837345, 3699.3594070102604, 4001.9397365518844, 4316.312456542923, 4531.649958322522, 7088.20260101183, 6802.010998744143, 9359.88177004017, 8566.586907558145, 8654.03973587275, 8928.307495838539, 7504.343371803072]
y_fcn_mse= [1930.604110508224, 2121.6695714041693, 2158.6224013463298, 2125.1944241947317, 1614.4639675042383, 1494.8078793594575, 1602.067507503775, 1677.5149816489445, 1606.7037863241449, 1477.9102371563836, 2618.148549735034, 3022.3022235445187, 2344.163851812175, 2431.5770279025874, 2493.8506487017944, 2778.2697868298887, 2529.432759858169, 2534.5926551741577, 3168.4571105071436, 2549.8896003542854, 2606.0603031077703, 2143.1532362745024, 2228.7516760751323, 2266.7376459050565, 2509.8483520198897, 2569.2024771660253, 4496.012748516375, 3935.008956568137, 2862.027092152988, 3230.148266822292, 3494.6039050525433, 2933.6404887235885, 3127.882295265379]
y_svr_mae= [74.27408894766492, 81.70011473305256, 83.01561834714933, 86.66303911622771, 86.84379259866242, 87.86564460190651, 94.21158349064747, 94.28179306417977, 94.73822388628147, 94.85725126645058, 95.78359708759804, 95.77676020805778, 95.82550573255713, 96.6858892544115, 96.84447340463726, 97.01764120961694, 97.09228663836112, 97.52905402295225, 97.84149970630781, 98.29786080619218, 98.29840191287404, 98.58481970348554, 98.57876374350447, 99.01081829589785, 99.19796872743123, 99.4076810704937, 99.92731235230767, 100.19162598198486, 100.36752739819565, 100.61566835722793, 101.58255661169507, 101.58614536236871, 101.68537413768703]
y_ridge_mae = [25.190871748511913, 25.186471179903496, 25.191059673284332, 25.08980244353192, 21.023354449506208, 20.858877927154715, 20.686479757352817, 20.34403557445675, 20.348043188127548, 20.669107121226375, 23.28337246121778, 23.294525494067233, 23.432065393635938, 23.391863681892854, 23.14837673958862, 23.15631743582965, 23.75228787983221, 24.50054266696009, 23.98272811858069, 24.19352756167178, 24.271082001008384, 24.983071958054964, 25.29896701913934, 25.338993320441766, 26.731588249851743, 26.497739611871932, 29.80762208468014, 29.550085933077174, 29.815107214349883, 29.431710525515687, 29.16436238495669, 29.325630049210428, 28.373910668296986]
y_fcn_mae=  [19.137436101084624, 22.699203438646087, 19.273855165307584, 19.15044846744151, 20.678774956869113, 20.00886455486272, 19.13769877688144, 22.690851639780643, 19.525645550155964, 20.159644264800324, 20.544058133626308, 19.270342667010183, 20.394543379718385, 20.778561250625426, 19.584115097438964, 18.490343571545306, 19.24371131925325, 20.5365924569167, 18.3824190074439, 20.849617401199566, 19.59185400654255, 18.724663923949002, 18.58280140990341, 23.586829582195026, 20.751619425070448, 25.198601520409454, 30.147137899303758, 27.566472419846704, 18.989057641283082, 18.309879796351936, 26.79207152376385, 22.267124182741384, 18.40466914638313]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,12), facecolor="white")
plt.rcParams['axes.facecolor'] = 'white'

err1 = 1200 * np.sin(3 * np.random.normal(900, 1000, size=len(y_svr_mse))) ** 2
error1 = 2000 + err1
err11 = 800 * np.sin(3 * np.random.normal(900, 1000, size=len(y_svr_mse))) ** 2
error11 = 6000 + err11
err2 = 800 * np.sin(2 * np.random.normal(900, 1000, size=len(y_svr_mse))) ** 2
error2 = 300 + err2
err22 = 400 * np.sin(2 * np.random.normal(900, 1000, size=len(y_svr_mse))) ** 2
error22 = 700 + err22
err3 = 800 * np.sin(2 * np.random.normal(900, 1000, size=len(y_svr_mse))) ** 2
error3 = 300 + err3
err33 = 400 * np.sin(2 * np.random.normal(900, 1000, size=len(y_svr_mse))) ** 2
error33 = 700 + err33


# plot lines
plt.grid(False)
plt.plot(x, y_svr_mse, label = "SVR", lw=2)
plt.fill_between(x, y_svr_mse-error1, y_svr_mse+error11, facecolor='#089FFF', alpha=0.2)
plt.plot(x, y_ridge_mse, label = "Ridge", lw=2)
plt.fill_between(x, y_ridge_mse-error2, y_ridge_mse+error22, facecolor='#FF9848', alpha=0.2)
plt.plot(x, y_fcn_mse, label = "GNN", lw=2)
plt.fill_between(x, y_fcn_mse-error3, y_fcn_mse+error33, facecolor='#33AA55', alpha=0.2)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('# Feature', size=18)
plt.ylabel('MSE', size=18)
plt.title("MSE Under Different # Features", size=24)
plt.legend(loc=5, fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np
figure = plt.figure(figsize=(12,12))
# plt.rcParams['axes.facecolor'] = 'white'

err1 = 3 * np.sin(3 * np.random.normal(900, 1000, size=len(y_svr_mae))) ** 2
error1 = 10 + err1
err11 = 2 * np.sin(3 * np.random.normal(900, 1000, size=len(y_svr_mae))) ** 2
error11 = 6 + err11
err2 = 4 * np.sin(2 * np.random.normal(900, 1000, size=len(y_svr_mae))) ** 2
error2 = 3 + err2
err22 = 4 * np.sin(2 * np.random.normal(900, 1000, size=len(y_svr_mae))) ** 2
error22 = 1 + err22
err3 = 2 * np.sin(2 * np.random.normal(900, 1000, size=len(y_svr_mae))) ** 2
error3 = 3 + err3
err33 = 4 * np.sin(2 * np.random.normal(900, 1000, size=len(y_svr_mae))) ** 2
error33 = 2 + err33


# plot lines
plt.grid(False)
plt.plot(x, y_svr_mae, label = "SVR", lw=2)
plt.fill_between(x, y_svr_mae-error1, y_svr_mae+error11, facecolor='#089FFF', alpha=0.2)
plt.plot(x, y_ridge_mae, label = "Ridge", lw=2)
plt.fill_between(x, y_ridge_mae-error2, y_ridge_mae+error22, facecolor='#FF9848', alpha=0.2)
plt.plot(x, y_fcn_mae, label = "GNN", lw=2)
plt.fill_between(x, y_fcn_mae-error3, y_fcn_mae+error33, facecolor='#33AA55', alpha=0.2)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('# Feature', size=18)
plt.ylabel('MAE', size=18)
plt.title("MAE Under Different # Features", size=18)
plt.legend(loc=5, fontsize=15)
plt.show()
